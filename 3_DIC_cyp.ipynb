# %% [markdown]
# <a href="https://colab.research.google.com/github/cosio574/cyp_2021/blob/main/3_DIC_cyp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
coleccion={"Mario":20, "Mariana":19, "Yessica": 14, "Luis":18}
for i in coleccion:
  print(f"{coleccion [i]}")
# Out:
# 20
# 19
# 14
# 18

# %%
coleccion={"Mario":20, "Mariana":19, "Yessica":14, "Luis":18}
for i in coleccion:
 print(f"{i} ->{colección[i]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-8a97bc356ffa> in <module>()
#       1 coleccion={"Mario":20, "Mariana":19, "Yessica":14, "Luis":18}
#       2 for i in coleccion:
# ----> 3  print(f"{i} ->{colección[i]}")
#
# NameError: name 'colección' is not defined

# %%
email=False
for i in"ariel@unam.mx":

  if(i=="@"):
   email=True


if email==True:
  print("El email es correcto")

else:
    print("El correo no es correcto")
# Out:
# El email es correcto

# %%
email=False
myEmail=input("Introduce tu correo electronico")
for i in myEmail:
  if(i=="@"):
    email=True

if email:
  print("El email es correcto")

else:
  print("El coorreo no es correcto")
# Out:
# Introduce tu correo electronicocosiomarco21@gmail.com
# El email es correcto

# %%
for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#While ejemplos

i=1
while i <=10:
  print("Ejecucion"+ str(i))
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# ...

# %%
while <=10:
  print("Ejecucion"+str(i))

  i=i+1

# %%
edad=int(input("Introduce tu edad:"))
while edad < 0:
  print("Ha introducido una edad negativa, Intentalo de Nuevo")
  edad=int(input("Introduce tu edad"))
  print("Gracias por participar")
  print("Edad del aspirante"+ str (edad))
