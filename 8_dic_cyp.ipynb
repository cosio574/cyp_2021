# %% [markdown]
# <a href="https://colab.research.google.com/github/cosio574/cyp_2021/blob/main/8_dic_cyp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 20
while(a  > 10):
  print(f"A = {a}")
  a = a - 1
# Out:
# A = 20
# A = 19
# A = 18
# A = 17
# A = 16
# A = 15
# A = 14
# A = 13
# A = 12
# A = 11

# %%
suma_gas = 0
gasto = float(input("Introduce un gasto: "))
while(gasto != -1):
  suma_gas = suma_gas + gasto
  gasto = float(input("Introduce un gasto:"))
  print(f"La suma total es: {suma_gas} pesos")
# Out:
# Introduce un gasto: 1.1
# Introduce un gasto:2.2
# La suma total es: 1.1 pesos
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     565         """
# --> 566         parts = [self.recv(flags, copy=copy, track=track)]
# ...

# %%
sumpar = 0
sumimp = 0
cuepar = 0
I = 1

while I <= 5:
  num = int(input("Introduce un numero entero"))
  if num != 0:
    if ((-1)**num) > 0:
      sumpar = sumpar + num
      cuepar = cuepar + 1
    else:
      sumimp = sumimp + num
    I = I + 1
propar = sumpar / cuepar
print(f"El promedio de los pares es: { propar }")
print(f"La suma de los impares es: { sumimp }")
# Out:
# Introduce un numero entero1
# Introduce un numero entero2
# Introduce un numero entero3
# Introduce un numero entero4
# Introduce un numero entero5
# El promedio de los pares es: 3.0
# La suma de los impares es: 9

# %%
band = True
sumser = 0
I = 2
while I <=  1800:
  sumser = sumser + I
  print(f"{ I }, " , end = "")
  if band == True:
    band = False
    I = I + 3
  else:
      band = True
      I = I + 2
      print("La suma de la serie es: ", sumser)
# Out:
# 2, 5, La suma de la serie es:  7
# 7, 10, La suma de la serie es:  24
# 12, 15, La suma de la serie es:  51
# 17, 20, La suma de la serie es:  88
# 22, 25, La suma de la serie es:  135
# 27, 30, La suma de la serie es:  192
# 32, 35, La suma de la serie es:  259
# 37, 40, La suma de la serie es:  336
# 42, 45, La suma de la serie es:  423
# 47, 50, La suma de la serie es:  520
# 52, 55, La suma de la serie es:  627
# 57, 60, La suma de la serie es:  744
# 62, 65, La suma de la serie es:  871
# 67, 70, La suma de la serie es:  1008
# 72, 75, La suma de la serie es:  1155
# 77, 80, La suma de la serie es:  1312
# 82, 85, La suma de la serie es:  1479
# 87, 90, La suma de la serie es:  1656
# 92, 95, La suma de la serie es:  1843
# 97, 100, La suma de la serie es:  2040
# 102, 105, La suma de la serie es:  2247
# 107, 110, La suma de la serie es:  2464
# 112, 115, La suma de la serie es:  2691
# 117, 120, La suma de la serie es:  2928
# 122, 125, La suma de la serie es:  3175
# ...

# %%
s1 = 0
s2 = 0
s3 = 0
#...
s70 = 0

s1 = float(input("dame el sueldo"))
s2 = float(input("dame el sueldo"))
s3 = float(input("dame el sueldo"))
#...
s70 = float(input("dame el sueldo"))
